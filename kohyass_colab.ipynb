# %% [markdown]
# <a href="https://colab.research.google.com/github/baicai99/kohyass_colab/blob/main/kohyass_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kohya_ss 安装配置指南
#
# ## 前言
#
# 欢迎使用本指南，这是一份简化版的 kohya_ss 安装配置教程。本文档旨在帮助初学者快速完成安装过程，无需深入了解每个步骤的技术细节。
#
# 由于是周末的缘故，我只是制作了这个，但是没有用它跑过测试，如果有问题请提交issus。
#
# ## 使用方法
#
# 1. 按照本文档提供的步骤操作
# 2. 在每个代码块后按 `Shift + Enter` 执行命令
# 3. 一直执行到最后一个代码块
# 4. 完成后将自动生成一个网页链接
# 5. 点击该链接即可进入 kohya_ss 训练界面
#
# ## 注意事项
#
# - 这个服务生命周期只有 72 小时，请做好倒计时工作
# - 请确保按顺序执行每个步骤
# - 不要跳过任何代码块
# - 执行过程中请耐心等待，某些安装步骤可能需要较长时间
#
# 祝您使用愉快！

# %%
cd ../
# Out:
# /content

# %%
# 首先安装Python 3.11.0
# !apt-get update
# !apt-get install -y python3.11 python3.11-venv python3.11-dev

# 创建Python 3.11.0的虚拟环境
# !python3.11 -m venv py311env

# 使用绝对路径来调用虚拟环境中的Python
# !./py311env/bin/python --version
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (104 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...

# %% [markdown]
# 安装依赖的时间大约是7分钟，请耐心等待。

# %%
# 使用虚拟环境中的pip安装PyTorch相关包
# !./py311env/bin/pip install torch==2.1.2+cu118 torchvision==0.16.2+cu118 xformers==0.0.23.post1+cu118 --extra-index-url https://download.pytorch.org/whl/cu118

# 安装其他依赖包
# !./py311env/bin/pip install accelerate==0.25.0 aiofiles==23.2.1 altair==4.2.2
# !./py311env/bin/pip install dadaptation==3.1 diffusers[torch]==0.25.0 easygui==0.98.3
# !./py311env/bin/pip install einops==0.7.0 fairscale==0.4.13 ftfy==6.1.1 gradio==4.43.0
# !./py311env/bin/pip install huggingface-hub==0.20.1 imagesize==1.4.1 invisible-watermark==0.2.0
# !./py311env/bin/pip install lion-pytorch==0.0.6 lycoris_lora==2.2.0.post3 omegaconf==2.3.0
# !./py311env/bin/pip install onnx==1.16.1 prodigyopt==1.0 protobuf==3.20.3
# !./py311env/bin/pip install open-clip-torch==2.20.0 opencv-python==4.7.0.68
# !./py311env/bin/pip install pytorch-lightning==1.9.0 rich>=13.7.1 safetensors==0.4.3
# !./py311env/bin/pip install scipy==1.11.4 timm==1.0.15 tk==0.1.0 toml==0.10.2
# !./py311env/bin/pip install transformers==4.38.0 voluptuous==0.13.1 wandb==0.15.11

# 安装bitsandbytes
# !./py311env/bin/pip install bitsandbytes==0.43.0

# 安装TensorFlow和TensorBoard
# !./py311env/bin/pip install tensorboard==2.15.2 tensorflow==2.15.0.post1

# 安装ONNX运行时GPU版本
# !./py311env/bin/pip install onnxruntime-gpu==1.17.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#   Using cached huggingface_hub-0.20.1-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached huggingface_hub-0.20.1-py3-none-any.whl (330 kB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.29.3
#     Uninstalling huggingface-hub-0.29.3:
#       Successfully uninstalled huggingface-hub-0.29.3
# ...
#   Using cached timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# ...
# Using cached timm-1.0.15-py3-none-any.whl (2.4 MB)
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 0.6.12
#     Uninstalling timm-0.6.12:
#       Successfully uninstalled timm-0.6.12
# ...

# %%
# 重新克隆仓库（如果需要）
# %cd /content
# !git clone --recursive https://github.com/bmaltais/kohya_ss.git

# 切换到kohya_ss目录
# %cd kohya_ss
# Out:
# /content
# Cloning into 'kohya_ss'...
# remote: Enumerating objects: 14730, done.
# remote: Counting objects: 100% (449/449), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 14730 (delta 407), reused 351 (delta 350), pack-reused 14281 (from 4)
# Receiving objects: 100% (14730/14730), 23.04 MiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (10354/10354), done.
# Submodule 'sd-scripts' (https://github.com/kohya-ss/sd-scripts.git) registered for path 'sd-scripts'
# Cloning into '/content/kohya_ss/sd-scripts'...
# remote: Enumerating objects: 9227, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 9227 (delta 99), reused 52 (delta 49), pack-reused 9101 (from 3)
# Receiving objects: 100% (9227/9227), 11.54 MiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (6663/6663), done.
# Submodule path 'sd-scripts': checked out 'b8896aad400222c8c4441b217fda0f9bb0807ffd'
# /content/kohya_ss

# %%
# 使用Python 3.10虚拟环境启动GUI
# !../py311env/bin/python kohya_gui.py --share --headless
# Out:
# 2025-03-23 01:21:40.432722: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-23 01:21:40.432807: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-23 01:21:40.435345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 01:21:40.456715: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
